# %% [markdown]
# ## 1. The brief
# <p>Imagine working for a digital marketing agency, and the agency is approached by a massive online retailer of furniture. They want to test our skills at creating large campaigns for all of their website. We are tasked with creating a prototype set of keywords for search campaigns for their sofas section. The client says that they want us to generate keywords for the following products: </p>
# <ul>
# <li>sofas</li>
# <li>convertible sofas</li>
# <li>love seats</li>
# <li>recliners</li>
# <li>sofa beds</li>
# </ul>
# <p><strong>The brief</strong>: The client is generally a low-cost retailer, offering many promotions and discounts. We will need to focus on such keywords. We will also need to move away from luxury keywords and topics, as we are targeting price-sensitive customers. Because we are going to be tight on budget, it would be good to focus on a tightly targeted set of keywords and make sure they are all set to exact and phrase match.</p>
# <p>Based on the brief above we will first need to generate a list of words, that together with the products given above would make for good keywords. Here are some examples:</p>
# <ul>
# <li>Products: sofas, recliners</li>
# <li>Words: buy, prices</li>
# </ul>
# <p>The resulting keywords: 'buy sofas', 'sofas buy', 'buy recliners', 'recliners buy',
#           'prices sofas', 'sofas prices', 'prices recliners', 'recliners prices'.</p>
# <p>As a final result, we want to have a DataFrame that looks like this: </p>
# <table>
# <thead>
# <tr>
# <th>Campaign</th>
# <th>Ad Group</th>
# <th>Keyword</th>
# <th>Criterion Type</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1a</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1a</td>
# <td>Phrase</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1b</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_1</td>
# <td>keyword 1b</td>
# <td>Phrase</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_2</td>
# <td>keyword 2a</td>
# <td>Exact</td>
# </tr>
# <tr>
# <td>Campaign1</td>
# <td>AdGroup_2</td>
# <td>keyword 2a</td>
# <td>Phrase</td>
# </tr>
# </tbody>
# </table>
# <p>The first step is to come up with a list of words that users might use to express their desire in buying low-cost sofas.</p>

# %%
# List of words to pair with products
words = ['discount', 'promo','cheap','affordable','buy','shop']

# Print list of words
print(words)
# Out:
# ['discount', 'promo', 'cheap', 'affordable', 'buy', 'shop']

# %% [markdown]
# ## 2. Combine the words with the product names
# <p>Imagining all the possible combinations of keywords can be stressful! But not for us, because we are keyword ninjas! We know how to translate campaign briefs into Python data structures and can imagine the resulting DataFrames that we need to create.</p>
# <p>Now that we have brainstormed the words that work well with the brief that we received, it is now time to combine them with the product names to generate meaningful search keywords. We want to combine every word with every product once before, and once after, as seen in the example above.</p>
# <p>As a quick reminder, for the product 'recliners' and the words 'buy' and 'price' for example, we would want to generate the following combinations: </p>
# <p>buy recliners<br>
# recliners buy<br>
# price recliners<br>
# recliners price<br>
# …  </p>
# <p>and so on for all the words and products that we have.</p>

# %%
products = ['sofas', 'convertible sofas', 'love seats', 'recliners', 'sofa beds']

# Create an empty list
keywords_list = []

# Loop through products
for product in products :
    # Loop through words
    for word in words :
        # Append combinations
        keywords_list.append([product, product + ' ' + word])
        keywords_list.append([product, word + ' ' + product])
        
# Inspect keyword list
from pprint import pprint
pprint(keywords_list)
# Out:
# [['sofas', 'sofas discount'],
#  ['sofas', 'discount sofas'],
#  ['sofas', 'sofas promo'],
#  ['sofas', 'promo sofas'],
#  ['sofas', 'sofas cheap'],
#  ['sofas', 'cheap sofas'],
#  ['sofas', 'sofas affordable'],
#  ['sofas', 'affordable sofas'],
#  ['sofas', 'sofas buy'],
#  ['sofas', 'buy sofas'],
#  ['sofas', 'sofas shop'],
#  ['sofas', 'shop sofas'],
#  ['convertible sofas', 'convertible sofas discount'],
#  ['convertible sofas', 'discount convertible sofas'],
#  ['convertible sofas', 'convertible sofas promo'],
#  ['convertible sofas', 'promo convertible sofas'],
#  ['convertible sofas', 'convertible sofas cheap'],
#  ['convertible sofas', 'cheap convertible sofas'],
#  ['convertible sofas', 'convertible sofas affordable'],
#  ['convertible sofas', 'affordable convertible sofas'],
#  ['convertible sofas', 'convertible sofas buy'],
#  ['convertible sofas', 'buy convertible sofas'],
#  ['convertible sofas', 'convertible sofas shop'],
#  ['convertible sofas', 'shop convertible sofas'],
#  ['love seats', 'love seats discount'],
#  ['love seats', 'discount love seats'],
#  ['love seats', 'love seats promo'],
#  ['love seats', 'promo love seats'],
#  ['love seats', 'love seats cheap'],
#  ['love seats', 'cheap love seats'],
#  ['love seats', 'love seats affordable'],
#  ['love seats', 'affordable love seats'],
#  ['love seats', 'love seats buy'],
#  ['love seats', 'buy love seats'],
#  ['love seats', 'love seats shop'],
#  ['love seats', 'shop love seats'],
#  ['recliners', 'recliners discount'],
#  ['recliners', 'discount recliners'],
#  ['recliners', 'recliners promo'],
#  ['recliners', 'promo recliners'],
#  ['recliners', 'recliners cheap'],
#  ['recliners', 'cheap recliners'],
#  ['recliners', 'recliners affordable'],
#  ['recliners', 'affordable recliners'],
#  ['recliners', 'recliners buy'],
#  ['recliners', 'buy recliners'],
#  ['recliners', 'recliners shop'],
#  ['recliners', 'shop recliners'],
#  ['sofa beds', 'sofa beds discount'],
#  ['sofa beds', 'discount sofa beds'],
#  ['sofa beds', 'sofa beds promo'],
#  ['sofa beds', 'promo sofa beds'],
#  ['sofa beds', 'sofa beds cheap'],
#  ['sofa beds', 'cheap sofa beds'],
#  ['sofa beds', 'sofa beds affordable'],
#  ['sofa beds', 'affordable sofa beds'],
#  ['sofa beds', 'sofa beds buy'],
#  ['sofa beds', 'buy sofa beds'],
#  ['sofa beds', 'sofa beds shop'],
#  ['sofa beds', 'shop sofa beds']]

# %% [markdown]
# ## 3. Convert the list of lists into a DataFrame
# <p>Now we want to convert this list of lists into a DataFrame so we can easily manipulate it and manage the final output.</p>

# %%
# Load library
import pandas as pd

# Create a DataFrame from list
keywords_df = pd.DataFrame.from_records(keywords_list)

# Print the keywords DataFrame to explore it
print(keywords_df.head())
# Out:
#        0               1
# 0  sofas  sofas discount
# 1  sofas  discount sofas
# 2  sofas     sofas promo
# 3  sofas     promo sofas
# 4  sofas     sofas cheap

# %% [markdown]
# ## 4. Rename the columns of the DataFrame
# <p>Before we can upload this table of keywords, we will need to give the columns meaningful names. If we inspect the DataFrame we just created above, we can see that the columns are currently named <code>0</code> and <code>1</code>. <code>Ad Group</code> (example: "sofas") and <code>Keyword</code> (example: "sofas buy") are much more appropriate names.</p>

# %%
# Rename the columns of the DataFrame
keywords_df = pd.DataFrame.from_records(keywords_list)
keywords_df.columns = ['Ad Group','Keyword']
print(keywords_df)
# Out:
#              Ad Group                       Keyword
# 0               sofas                sofas discount
# 1               sofas                discount sofas
# 2               sofas                   sofas promo
# 3               sofas                   promo sofas
# 4               sofas                   sofas cheap
# 5               sofas                   cheap sofas
# 6               sofas              sofas affordable
# 7               sofas              affordable sofas
# 8               sofas                     sofas buy
# 9               sofas                     buy sofas
# 10              sofas                    sofas shop
# 11              sofas                    shop sofas
# 12  convertible sofas    convertible sofas discount
# 13  convertible sofas    discount convertible sofas
# 14  convertible sofas       convertible sofas promo
# 15  convertible sofas       promo convertible sofas
# 16  convertible sofas       convertible sofas cheap
# 17  convertible sofas       cheap convertible sofas
# 18  convertible sofas  convertible sofas affordable
# 19  convertible sofas  affordable convertible sofas
# 20  convertible sofas         convertible sofas buy
# 21  convertible sofas         buy convertible sofas
# 22  convertible sofas        convertible sofas shop
# 23  convertible sofas        shop convertible sofas
# 24         love seats           love seats discount
# 25         love seats           discount love seats
# 26         love seats              love seats promo
# 27         love seats              promo love seats
# 28         love seats              love seats cheap
# 29         love seats              cheap love seats
# 30         love seats         love seats affordable
# 31         love seats         affordable love seats
# 32         love seats                love seats buy
# 33         love seats                buy love seats
# 34         love seats               love seats shop
# 35         love seats               shop love seats
# 36          recliners            recliners discount
# 37          recliners            discount recliners
# 38          recliners               recliners promo
# 39          recliners               promo recliners
# 40          recliners               recliners cheap
# 41          recliners               cheap recliners
# 42          recliners          recliners affordable
# 43          recliners          affordable recliners
# 44          recliners                 recliners buy
# 45          recliners                 buy recliners
# 46          recliners                recliners shop
# 47          recliners                shop recliners
# 48          sofa beds            sofa beds discount
# 49          sofa beds            discount sofa beds
# 50          sofa beds               sofa beds promo
# 51          sofa beds               promo sofa beds
# 52          sofa beds               sofa beds cheap
# 53          sofa beds               cheap sofa beds
# 54          sofa beds          sofa beds affordable
# 55          sofa beds          affordable sofa beds
# 56          sofa beds                 sofa beds buy
# 57          sofa beds                 buy sofa beds
# 58          sofa beds                sofa beds shop
# 59          sofa beds                shop sofa beds

# %% [markdown]
# ## 5. Add a campaign column
# <p>Now we need to add some additional information to our DataFrame.
# We need a new column called <code>Campaign</code> for the campaign name. We want campaign names to be descriptive of our group of keywords and products, so let's call this campaign 'SEM_Sofas'.</p>

# %%
# Add a campaign column
keywords_df.insert(0, 'Campaign', 'SEM_Sofas')
print(keywords_df)
# Out:
#      Campaign           Ad Group                       Keyword
# 0   SEM_Sofas              sofas                sofas discount
# 1   SEM_Sofas              sofas                discount sofas
# 2   SEM_Sofas              sofas                   sofas promo
# 3   SEM_Sofas              sofas                   promo sofas
# 4   SEM_Sofas              sofas                   sofas cheap
# 5   SEM_Sofas              sofas                   cheap sofas
# 6   SEM_Sofas              sofas              sofas affordable
# 7   SEM_Sofas              sofas              affordable sofas
# 8   SEM_Sofas              sofas                     sofas buy
# 9   SEM_Sofas              sofas                     buy sofas
# 10  SEM_Sofas              sofas                    sofas shop
# 11  SEM_Sofas              sofas                    shop sofas
# 12  SEM_Sofas  convertible sofas    convertible sofas discount
# 13  SEM_Sofas  convertible sofas    discount convertible sofas
# 14  SEM_Sofas  convertible sofas       convertible sofas promo
# 15  SEM_Sofas  convertible sofas       promo convertible sofas
# 16  SEM_Sofas  convertible sofas       convertible sofas cheap
# 17  SEM_Sofas  convertible sofas       cheap convertible sofas
# 18  SEM_Sofas  convertible sofas  convertible sofas affordable
# 19  SEM_Sofas  convertible sofas  affordable convertible sofas
# 20  SEM_Sofas  convertible sofas         convertible sofas buy
# 21  SEM_Sofas  convertible sofas         buy convertible sofas
# 22  SEM_Sofas  convertible sofas        convertible sofas shop
# 23  SEM_Sofas  convertible sofas        shop convertible sofas
# 24  SEM_Sofas         love seats           love seats discount
# 25  SEM_Sofas         love seats           discount love seats
# 26  SEM_Sofas         love seats              love seats promo
# 27  SEM_Sofas         love seats              promo love seats
# 28  SEM_Sofas         love seats              love seats cheap
# 29  SEM_Sofas         love seats              cheap love seats
# 30  SEM_Sofas         love seats         love seats affordable
# 31  SEM_Sofas         love seats         affordable love seats
# 32  SEM_Sofas         love seats                love seats buy
# 33  SEM_Sofas         love seats                buy love seats
# 34  SEM_Sofas         love seats               love seats shop
# 35  SEM_Sofas         love seats               shop love seats
# 36  SEM_Sofas          recliners            recliners discount
# 37  SEM_Sofas          recliners            discount recliners
# 38  SEM_Sofas          recliners               recliners promo
# 39  SEM_Sofas          recliners               promo recliners
# 40  SEM_Sofas          recliners               recliners cheap
# 41  SEM_Sofas          recliners               cheap recliners
# 42  SEM_Sofas          recliners          recliners affordable
# 43  SEM_Sofas          recliners          affordable recliners
# 44  SEM_Sofas          recliners                 recliners buy
# 45  SEM_Sofas          recliners                 buy recliners
# 46  SEM_Sofas          recliners                recliners shop
# 47  SEM_Sofas          recliners                shop recliners
# 48  SEM_Sofas          sofa beds            sofa beds discount
# 49  SEM_Sofas          sofa beds            discount sofa beds
# 50  SEM_Sofas          sofa beds               sofa beds promo
# 51  SEM_Sofas          sofa beds               promo sofa beds
# 52  SEM_Sofas          sofa beds               sofa beds cheap
# 53  SEM_Sofas          sofa beds               cheap sofa beds
# 54  SEM_Sofas          sofa beds          sofa beds affordable
# 55  SEM_Sofas          sofa beds          affordable sofa beds
# 56  SEM_Sofas          sofa beds                 sofa beds buy
# 57  SEM_Sofas          sofa beds                 buy sofa beds
# 58  SEM_Sofas          sofa beds                sofa beds shop
# 59  SEM_Sofas          sofa beds                shop sofa beds

# %% [markdown]
# ## 6. Create the match type column
# <p>There are different keyword match types. One is exact match, which is for matching the exact term or are close variations of that exact term. Another match type is broad match, which means ads may show on searches that include misspellings, synonyms, related searches, and other relevant variations.</p>
# <p>Straight from Google's AdWords <a href="https://support.google.com/google-ads/answer/2497836?hl=en">documentation</a>:</p>
# <blockquote>
#   <p>In general, the broader the match type, the more traffic potential that keyword will have, since your ads may be triggered more often. Conversely, a narrower match type means that your ads may show less often—but when they do, they’re likely to be more related to someone’s search.</p>
# </blockquote>
# <p>Since the client is tight on budget, we want to make sure all the keywords are in exact match at the beginning.</p>

# %%
# Add a criterion type column
keywords_df['Criterion Type'] ='Exact'
print(keywords_df)
# Out:
#      Campaign           Ad Group                       Keyword Criterion Type
# 0   SEM_Sofas              sofas                sofas discount          Exact
# 1   SEM_Sofas              sofas                discount sofas          Exact
# 2   SEM_Sofas              sofas                   sofas promo          Exact
# 3   SEM_Sofas              sofas                   promo sofas          Exact
# 4   SEM_Sofas              sofas                   sofas cheap          Exact
# 5   SEM_Sofas              sofas                   cheap sofas          Exact
# 6   SEM_Sofas              sofas              sofas affordable          Exact
# 7   SEM_Sofas              sofas              affordable sofas          Exact
# 8   SEM_Sofas              sofas                     sofas buy          Exact
# 9   SEM_Sofas              sofas                     buy sofas          Exact
# 10  SEM_Sofas              sofas                    sofas shop          Exact
# 11  SEM_Sofas              sofas                    shop sofas          Exact
# 12  SEM_Sofas  convertible sofas    convertible sofas discount          Exact
# 13  SEM_Sofas  convertible sofas    discount convertible sofas          Exact
# 14  SEM_Sofas  convertible sofas       convertible sofas promo          Exact
# 15  SEM_Sofas  convertible sofas       promo convertible sofas          Exact
# 16  SEM_Sofas  convertible sofas       convertible sofas cheap          Exact
# 17  SEM_Sofas  convertible sofas       cheap convertible sofas          Exact
# 18  SEM_Sofas  convertible sofas  convertible sofas affordable          Exact
# 19  SEM_Sofas  convertible sofas  affordable convertible sofas          Exact
# 20  SEM_Sofas  convertible sofas         convertible sofas buy          Exact
# 21  SEM_Sofas  convertible sofas         buy convertible sofas          Exact
# 22  SEM_Sofas  convertible sofas        convertible sofas shop          Exact
# 23  SEM_Sofas  convertible sofas        shop convertible sofas          Exact
# 24  SEM_Sofas         love seats           love seats discount          Exact
# 25  SEM_Sofas         love seats           discount love seats          Exact
# 26  SEM_Sofas         love seats              love seats promo          Exact
# 27  SEM_Sofas         love seats              promo love seats          Exact
# 28  SEM_Sofas         love seats              love seats cheap          Exact
# 29  SEM_Sofas         love seats              cheap love seats          Exact
# 30  SEM_Sofas         love seats         love seats affordable          Exact
# 31  SEM_Sofas         love seats         affordable love seats          Exact
# 32  SEM_Sofas         love seats                love seats buy          Exact
# 33  SEM_Sofas         love seats                buy love seats          Exact
# 34  SEM_Sofas         love seats               love seats shop          Exact
# 35  SEM_Sofas         love seats               shop love seats          Exact
# 36  SEM_Sofas          recliners            recliners discount          Exact
# 37  SEM_Sofas          recliners            discount recliners          Exact
# 38  SEM_Sofas          recliners               recliners promo          Exact
# 39  SEM_Sofas          recliners               promo recliners          Exact
# 40  SEM_Sofas          recliners               recliners cheap          Exact
# 41  SEM_Sofas          recliners               cheap recliners          Exact
# 42  SEM_Sofas          recliners          recliners affordable          Exact
# 43  SEM_Sofas          recliners          affordable recliners          Exact
# 44  SEM_Sofas          recliners                 recliners buy          Exact
# 45  SEM_Sofas          recliners                 buy recliners          Exact
# 46  SEM_Sofas          recliners                recliners shop          Exact
# 47  SEM_Sofas          recliners                shop recliners          Exact
# 48  SEM_Sofas          sofa beds            sofa beds discount          Exact
# 49  SEM_Sofas          sofa beds            discount sofa beds          Exact
# 50  SEM_Sofas          sofa beds               sofa beds promo          Exact
# 51  SEM_Sofas          sofa beds               promo sofa beds          Exact
# 52  SEM_Sofas          sofa beds               sofa beds cheap          Exact
# 53  SEM_Sofas          sofa beds               cheap sofa beds          Exact
# 54  SEM_Sofas          sofa beds          sofa beds affordable          Exact
# 55  SEM_Sofas          sofa beds          affordable sofa beds          Exact
# 56  SEM_Sofas          sofa beds                 sofa beds buy          Exact
# 57  SEM_Sofas          sofa beds                 buy sofa beds          Exact
# 58  SEM_Sofas          sofa beds                sofa beds shop          Exact
# 59  SEM_Sofas          sofa beds                shop sofa beds          Exact

# %% [markdown]
# ## 7. Duplicate all the keywords into 'phrase' match
# <p>The great thing about exact match is that it is very specific, and we can control the process very well. The tradeoff, however, is that:  </p>
# <ol>
# <li>The search volume for exact match is lower than other match types</li>
# <li>We can't possibly think of all the ways in which people search, and so, we are probably missing out on some high-quality keywords.</li>
# </ol>
# <p>So it's good to use another match called <em>phrase match</em> as a discovery mechanism to allow our ads to be triggered by keywords that include our exact match keywords, together with anything before (or after) them.</p>
# <p>Later on, when we launch the campaign, we can explore with modified broad match, broad match, and negative match types, for better visibility and control of our campaigns.</p>

# %%
# Make a copy of the keywords DataFrame
keywords_phrase = keywords_df.copy()

# Change criterion type match to phrase
keywords_phrase['Criterion Type']= 'Phrase'

# Append the DataFrames
keywords_df_final = keywords_df.append(keywords_phrase)
print(keywords_df_final)
# Out:
#      Campaign           Ad Group                       Keyword Criterion Type
# 0   SEM_Sofas              sofas                sofas discount          Exact
# 1   SEM_Sofas              sofas                discount sofas          Exact
# 2   SEM_Sofas              sofas                   sofas promo          Exact
# 3   SEM_Sofas              sofas                   promo sofas          Exact
# 4   SEM_Sofas              sofas                   sofas cheap          Exact
# 5   SEM_Sofas              sofas                   cheap sofas          Exact
# 6   SEM_Sofas              sofas              sofas affordable          Exact
# 7   SEM_Sofas              sofas              affordable sofas          Exact
# 8   SEM_Sofas              sofas                     sofas buy          Exact
# 9   SEM_Sofas              sofas                     buy sofas          Exact
# 10  SEM_Sofas              sofas                    sofas shop          Exact
# 11  SEM_Sofas              sofas                    shop sofas          Exact
# 12  SEM_Sofas  convertible sofas    convertible sofas discount          Exact
# 13  SEM_Sofas  convertible sofas    discount convertible sofas          Exact
# 14  SEM_Sofas  convertible sofas       convertible sofas promo          Exact
# 15  SEM_Sofas  convertible sofas       promo convertible sofas          Exact
# 16  SEM_Sofas  convertible sofas       convertible sofas cheap          Exact
# 17  SEM_Sofas  convertible sofas       cheap convertible sofas          Exact
# 18  SEM_Sofas  convertible sofas  convertible sofas affordable          Exact
# 19  SEM_Sofas  convertible sofas  affordable convertible sofas          Exact
# 20  SEM_Sofas  convertible sofas         convertible sofas buy          Exact
# 21  SEM_Sofas  convertible sofas         buy convertible sofas          Exact
# 22  SEM_Sofas  convertible sofas        convertible sofas shop          Exact
# 23  SEM_Sofas  convertible sofas        shop convertible sofas          Exact
# 24  SEM_Sofas         love seats           love seats discount          Exact
# 25  SEM_Sofas         love seats           discount love seats          Exact
# 26  SEM_Sofas         love seats              love seats promo          Exact
# 27  SEM_Sofas         love seats              promo love seats          Exact
# 28  SEM_Sofas         love seats              love seats cheap          Exact
# 29  SEM_Sofas         love seats              cheap love seats          Exact
# ..        ...                ...                           ...            ...
# 30  SEM_Sofas         love seats         love seats affordable         Phrase
# 31  SEM_Sofas         love seats         affordable love seats         Phrase
# 32  SEM_Sofas         love seats                love seats buy         Phrase
# 33  SEM_Sofas         love seats                buy love seats         Phrase
# 34  SEM_Sofas         love seats               love seats shop         Phrase
# 35  SEM_Sofas         love seats               shop love seats         Phrase
# 36  SEM_Sofas          recliners            recliners discount         Phrase
# 37  SEM_Sofas          recliners            discount recliners         Phrase
# 38  SEM_Sofas          recliners               recliners promo         Phrase
# 39  SEM_Sofas          recliners               promo recliners         Phrase
# 40  SEM_Sofas          recliners               recliners cheap         Phrase
# 41  SEM_Sofas          recliners               cheap recliners         Phrase
# 42  SEM_Sofas          recliners          recliners affordable         Phrase
# 43  SEM_Sofas          recliners          affordable recliners         Phrase
# 44  SEM_Sofas          recliners                 recliners buy         Phrase
# 45  SEM_Sofas          recliners                 buy recliners         Phrase
# 46  SEM_Sofas          recliners                recliners shop         Phrase
# 47  SEM_Sofas          recliners                shop recliners         Phrase
# 48  SEM_Sofas          sofa beds            sofa beds discount         Phrase
# 49  SEM_Sofas          sofa beds            discount sofa beds         Phrase
# 50  SEM_Sofas          sofa beds               sofa beds promo         Phrase
# 51  SEM_Sofas          sofa beds               promo sofa beds         Phrase
# 52  SEM_Sofas          sofa beds               sofa beds cheap         Phrase
# 53  SEM_Sofas          sofa beds               cheap sofa beds         Phrase
# 54  SEM_Sofas          sofa beds          sofa beds affordable         Phrase
# 55  SEM_Sofas          sofa beds          affordable sofa beds         Phrase
# 56  SEM_Sofas          sofa beds                 sofa beds buy         Phrase
# 57  SEM_Sofas          sofa beds                 buy sofa beds         Phrase
# 58  SEM_Sofas          sofa beds                sofa beds shop         Phrase
# 59  SEM_Sofas          sofa beds                shop sofa beds         Phrase
#
# [120 rows x 4 columns]

# %% [markdown]
# ## 8. Save and summarize!
# <p>To upload our campaign, we need to save it as a CSV file. Then we will be able to import it to AdWords editor or BingAds editor. There is also the option of pasting the data into the editor if we want, but having easy access to the saved data is great so let's save to a CSV file!</p>
# <p>Looking at a summary of our campaign structure is good now that we've wrapped up our keyword work. We can do that by grouping by ad group and criterion type and counting by keyword. This summary shows us that we assigned specific keywords to specific ad groups, which are each part of a campaign. In essence, we are telling Google (or Bing, etc.) that we want any of the words in each ad group to trigger one of the ads in the same ad group. Separately, we will have to create another table for ads, which is a task for another day and would look something like this:</p>
# <table>
# <thead>
# <tr>
# <th>Campaign</th>
# <th>Ad Group</th>
# <th>Headline 1</th>
# <th>Headline 2</th>
# <th>Description</th>
# <th>Final URL</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>SEM_Sofas</td>
# <td>Sofas</td>
# <td>Looking for Quality Sofas?</td>
# <td>Explore Our Massive Collection</td>
# <td>30-day Returns With Free Delivery Within the US. Start Shopping Now</td>
# <td>DataCampSofas.com/sofas</td>
# </tr>
# <tr>
# <td>SEM_Sofas</td>
# <td>Sofas</td>
# <td>Looking for Affordable Sofas?</td>
# <td>Check Out Our Weekly Offers</td>
# <td>30-day Returns With Free Delivery Within the US. Start Shopping Now</td>
# <td>DataCampSofas.com/sofas</td>
# </tr>
# <tr>
# <td>SEM_Sofas</td>
# <td>Recliners</td>
# <td>Looking for Quality Recliners?</td>
# <td>Explore Our Massive Collection</td>
# <td>30-day Returns With Free Delivery Within the US. Start Shopping Now</td>
# <td>DataCampSofas.com/recliners</td>
# </tr>
# <tr>
# <td>SEM_Sofas</td>
# <td>Recliners</td>
# <td>Need Affordable Recliners?</td>
# <td>Check Out Our Weekly Offers</td>
# <td>30-day Returns With Free Delivery Within the US. Start Shopping Now</td>
# <td>DataCampSofas.com/recliners</td>
# </tr>
# </tbody>
# </table>
# <p>Together, these tables get us the sample <strong>keywords -> ads -> landing pages</strong> mapping shown in the diagram below.</p>
# <p><img src="https://assets.datacamp.com/production/project_400/img/kwds_ads_lpages.png" alt="Keywords-Ads-Landing pages flow"></p>

# %%
# Save the final keywords to a CSV file
keywords_df_final.to_csv('keywords.csv', index = False)

# View a summary of our campaign work
summary = keywords_df_final.groupby(['Ad Group', 'Criterion Type'])['Keyword'].count()
print(summary)
# Out:
# Ad Group           Criterion Type
# convertible sofas  Exact             12
#                    Phrase            12
# love seats         Exact             12
#                    Phrase            12
# recliners          Exact             12
#                    Phrase            12
# sofa beds          Exact             12
#                    Phrase            12
# sofas              Exact             12
#                    Phrase            12
# Name: Keyword, dtype: int64
